# %%
import pandas as pd

# %%
df19 = pd.read_csv('https://query.data.world/s/2kbvelekrjyn7645pfonx3noeskckg')
df20 = pd.read_csv('https://query.data.world/s/citpih6iapqsuvyltsunujv77y3qla')
df17 = pd.read_csv('https://query.data.world/s/j33nxkkicnv3tlo5txkjxxxzsnefbl')

# %% [markdown]
# # **DATA EXPLORATION**

# %% [markdown]
# ## **DF20 PREPROCESSING**

# %%
df20.head(3)
# Out:
#                        Job Title  \
# 0                  Shift Manager
# 1     Operations Support Manager
# 2  Senior Product Manager - Data
#
#                                      Job Description  Job Type  Categories  \
# 0  <div id="jobDescriptionText" class="jobsearch-...       NaN         NaN
# 1  <div id="jobDescriptionText" class="jobsearch-...       NaN         NaN
# 2  <div id="jobDescriptionText" class="jobsearch-...       NaN         NaN
#
#                   Location           City State        Country Zip Code  \
# 0  Mission Hills, CA 91345  Mission Hills    CA  United States    91345
# 1        Atlanta, GA 30342        Atlanta    GA  United States    30342
# 2              Chicago, IL        Chicago    IL  United States      NaN
#
#    Address  ...  Employer Phone  \
# 0      NaN  ...             NaN
# 1      NaN  ...             NaN
# 2      NaN  ...             NaN
#
#                                        Employer Logo  \
# ...

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30002 entries, 0 to 30001
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job Title           30002 non-null  object
#  1   Job Description     30002 non-null  object
#  2   Job Type            0 non-null      float64
#  3   Categories          0 non-null      float64
#  4   Location            30002 non-null  object
#  5   City                30002 non-null  object
#  6   State               30002 non-null  object
#  7   Country             30002 non-null  object
#  8   Zip Code            16252 non-null  object
#  9   Address             0 non-null      float64
#  10  Salary From         0 non-null      float64
#  11  Salary To           0 non-null      float64
#  12  Salary Period       0 non-null      float64
#  13  Apply Url           18392 non-null  object
#  14  Apply Email         0 non-null      float64
# ...

# %%
#dropping null columns
df20 = df20.drop(["Job Type", "Categories", "Address", "Salary From", "Salary To", "Salary Period", "Apply Email", "Employees", "Industry", "Employer Email", "Employer Website", "Employer Phone"], axis=1)

# %%
#Fillna
df20 = df20.fillna("None")
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30002 entries, 0 to 30001
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job Title           30002 non-null  object
#  1   Job Description     30002 non-null  object
#  2   Location            30002 non-null  object
#  3   City                30002 non-null  object
#  4   State               30002 non-null  object
#  5   Country             30002 non-null  object
#  6   Zip Code            30002 non-null  object
#  7   Apply Url           30002 non-null  object
#  8   Company Name        30002 non-null  object
#  9   Employer Logo       30002 non-null  object
#  10  Companydescription  30002 non-null  object
#  11  Employer Location   30002 non-null  object
#  12  Employer City       30002 non-null  object
#  13  Employer State      30002 non-null  object
#  14  Employer Country    30002 non-null  object
# ...

# %%
df20.head(3)
# Out:
#                        Job Title  \
# 0                  Shift Manager
# 1     Operations Support Manager
# 2  Senior Product Manager - Data
#
#                                      Job Description                 Location  \
# 0  <div id="jobDescriptionText" class="jobsearch-...  Mission Hills, CA 91345
# 1  <div id="jobDescriptionText" class="jobsearch-...        Atlanta, GA 30342
# 2  <div id="jobDescriptionText" class="jobsearch-...              Chicago, IL
#
#             City State        Country Zip Code Apply Url  Company Name  \
# 0  Mission Hills    CA  United States    91345      None  Del Taco LLC
# 1        Atlanta    GA  United States    30342      None  FOCUS Brands
# 2        Chicago    IL  United States     None      None         Vibes
#
#                                        Employer Logo  \
# 0  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 1  https://d2q79iu7y748jz.cloudfront.net/s/_logo/...
# 2                                               None
#
# ...

# %% [markdown]
# ## **DF19 PREPROCESSING**

# %%
df19.head(3)
# Out:
#              crawl_timestamp  \
# 0  2019-02-06 05:26:22 +0000
# 1  2019-02-06 05:33:41 +0000
# 2  2019-02-06 05:33:35 +0000
#
#                                                  url  \
# 0  https://www.indeed.com/viewjob?jk=fd83355c2b23...
# 1  https://www.dice.com/jobs/detail/Data-Scientis...
# 2  https://www.dice.com/jobs/detail/Data-Scientis...
#
#                      job_title            category  \
# 0  Enterprise Data Scientist I  Accounting/Finance
# 1               Data Scientist                 NaN
# 2               Data Scientist                 NaN
#
#                            company_name            city state country  \
# 0               Farmers Insurance Group  Woodland Hills    CA     Usa
# 1                        Luxoft USA Inc      Middletown    NJ     Usa
# 2  Cincinnati Bell Technology Solutions        New York    NY     Usa
#
#     inferred_city inferred_state  ...  \
# 0  Woodland hills     California  ...
# 1      Middletown     New jersey  ...
# ...

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   crawl_timestamp       10000 non-null  object
#  1   url                   10000 non-null  object
#  2   job_title             10000 non-null  object
#  3   category              9118 non-null   object
#  4   company_name          9999 non-null   object
#  5   city                  9751 non-null   object
#  6   state                 9584 non-null   object
#  7   country               10000 non-null  object
#  8   inferred_city         8980 non-null   object
#  9   inferred_state        9484 non-null   object
#  10  inferred_country      9505 non-null   object
#  11  post_date             10000 non-null  object
#  12  job_description       10000 non-null  object
#  13  job_type              10000 non-null  object
#  14  salary_offered        597 non-null    object
# ...

# %%
print(df19["salary_offered"])
# Out:
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                 ...
# 9995    $100k - 135k | Equity
# 9996                      NaN
# 9997                      NaN
# 9998                      NaN
# 9999                      NaN
# Name: salary_offered, Length: 10000, dtype: object

# %%
#dropping null columns
df19 = df19.drop(["contact_email", "contact_phone_number"], axis=1)

# %%
#Convert salary to Int
df19["salary_offered"] = pd.to_numeric(df19["salary_offered"], errors='ignore')
print(df19["salary_offered"])
# Out:
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                 ...
# 9995    $100k - 135k | Equity
# 9996                      NaN
# 9997                      NaN
# 9998                      NaN
# 9999                      NaN
# Name: salary_offered, Length: 10000, dtype: object

# %%
#null salaries with mean #doesnt work because salaries are not numeric
df19["salary_offered"] = df19["salary_offered"].fillna(df19["salary_offered"].mean())
df19["salary_offered"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-f9ed3765ea72> in <module>()
#       1 #null salaries with mean
# ----> 2 df19["salary_offered"] = df19["salary_offered"].fillna(df19["salary_offered"].mean())
#       3 df19["salary_offered"]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# ...

# %%
#Fillna
df19 = df19.fillna("None")
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   crawl_timestamp       10000 non-null  object
#  1   url                   10000 non-null  object
#  2   job_title             10000 non-null  object
#  3   category              10000 non-null  object
#  4   company_name          10000 non-null  object
#  5   city                  10000 non-null  object
#  6   state                 10000 non-null  object
#  7   country               10000 non-null  object
#  8   inferred_city         10000 non-null  object
#  9   inferred_state        10000 non-null  object
#  10  inferred_country      10000 non-null  object
#  11  post_date             10000 non-null  object
#  12  job_description       10000 non-null  object
#  13  job_type              10000 non-null  object
#  14  salary_offered        10000 non-null  object
# ...

# %% [markdown]
# ## **DF17 PREPROCESSING**

# %%
df17.head(3)
# Out:
#                                        advertiserurl  \
# 0  https://www.dice.com/jobs/detail/AUTOMATION-TE...
# 1  https://www.dice.com/jobs/detail/Information-S...
# 2  https://www.dice.com/jobs/detail/Business-Solu...
#
#                              company  \
# 0  Digital Intelligence Systems, LLC
# 1  University of Chicago/IT Services
# 2               Galaxy Systems, Inc.
#
#                             employmenttype_jobstatus  \
# 0  C2H Corp-To-Corp, C2H Independent, C2H W2, 3 M...
# 1                                          Full Time
# 2                                          Full Time
#
#                                       jobdescription               jobid  \
# 0  Looking for Selenium engineers...must have sol...  Dice Id : 10110693
# 1  The University of Chicago has a rapidly growin...  Dice Id : 10114469
# 2  GalaxE.SolutionsEvery day, our solutions affec...  Dice Id : CXGALXYS
#
#   joblocation_address                       jobtitle     postdate  \
# ...

# %%
df17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   advertiserurl             22000 non-null  object
#  1   company                   21950 non-null  object
#  2   employmenttype_jobstatus  21770 non-null  object
#  3   jobdescription            22000 non-null  object
#  4   jobid                     22000 non-null  object
#  5   joblocation_address       21997 non-null  object
#  6   jobtitle                  22000 non-null  object
#  7   postdate                  22000 non-null  object
#  8   shift                     21643 non-null  object
#  9   site_name                 3490 non-null   object
#  10  skills                    21957 non-null  object
#  11  uniq_id                   22000 non-null  object
# dtypes: object(12)
# memory usage: 2.0+ MB
